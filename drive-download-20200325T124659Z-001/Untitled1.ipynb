# %%
from google.colab import drive


drive.mount('/content/gdrive')

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 32549 (delta 3), reused 8 (delta 0), pack-reused 32538
# Receiving objects: 100% (32549/32549), 511.86 MiB | 34.88 MiB/s, done.
# Resolving deltas: 100% (20838/20838), done.
# Checking out files: 100% (2487/2487), done.

# %%
# !export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim

# %%
import pandas as pd

data = pd.read_csv('test.csv', header=0)
data
# Out:
#     Unnamed: 0    filename  width  height class  xmin  ymin  xmax  ymax
# 0            0  000121.jpg   2448    2048  sign  1046   960  1059   972
# 1            1  000121.jpg   2448    2048  sign  1045   973  1060   981
# 2            2  000121.jpg   2448    2048  sign  1050   982  1057   994
# 3            3  000121.jpg   2448    2048  sign  1247   954  1258   968
# 4            4  000121.jpg   2448    2048  sign  1248   970  1258   975
# 5            5  000121.jpg   2448    2048  sign  1252   977  1258   990
# 6            6  000093.jpg   2448    2048  sign  1922   633  2071   779
# 7            7  000000.jpg   2448    2048  sign  1708   829  1762   893
# 8            8  000060.jpg   2448    2048  sign  1651   761  1729   854
# 9            9  000033.jpg   2448    2048  sign  1604   802  1679   874
# 10          10  000153.jpg   2448    2048  sign  1023   975  1037   987
# 11          11  000153.jpg   2448    2048  sign  1021   990  1037   998
# 12          12  000153.jpg   2448    2048  sign  1027   999  1034  1013
# 13          13  000153.jpg   2448    2048  sign  1241   969  1251   983
# 14          14  000153.jpg   2448    2048  sign  1241   985  1251   992
# 15          15  000153.jpg   2448    2048  sign  1245   992  1252  1007
# 16          16  000333.jpg   2448    2048  sign   784   990   803  1029
# 17          17  000333.jpg   2448    2048  sign   771   968   812   987
# 18          18  000333.jpg   2448    2048  sign   770   926   809   966
# 19          19  000333.jpg   2448    2048  sign  1370   974  1388  1014
# 20          20  000333.jpg   2448    2048  sign  1357   951  1397   973
# 21          21  000333.jpg   2448    2048  sign  1355   909  1396   950
# 22          22  000180.jpg   2448    2048  sign   999   971  1013   984
# 23          23  000180.jpg   2448    2048  sign   997   985  1014   993
# 24          24  000180.jpg   2448    2048  sign  1003   995  1011  1010
# 25          25  000180.jpg   2448    2048  sign  1235   963  1248   978
# 26          26  000180.jpg   2448    2048  sign  1234   980  1247   987
# 27          27  000180.jpg   2448    2048  sign  1239   989  1247  1004
# 28          28  000213.jpg   2448    2048  sign   986   965  1001   980
# 29          29  000213.jpg   2448    2048  sign   985   983  1004   992

# %%
data[data['filename']=='000333.jpg'].loc[:, 'width':'ymax']
# Out:
#     width  height class  xmin  ymin  xmax  ymax
# 16   2448    2048  sign   784   990   803  1029
# 17   2448    2048  sign   771   968   812   987
# 18   2448    2048  sign   770   926   809   966
# 19   2448    2048  sign  1370   974  1388  1014
# 20   2448    2048  sign  1357   951  1397   973
# 21   2448    2048  sign  1355   909  1396   950

# %%
def groupby(df):
    fnames = set(df['filename'])
    for i in fnames:
# Out:
# {'000000.jpg': [7],
#  '000033.jpg': [9],
#  '000060.jpg': [8],
#  '000093.jpg': [6],
#  '000121.jpg': [0, 1, 2, 3, 4, 5],
#  '000153.jpg': [10, 11, 12, 13, 14, 15],
#  '000180.jpg': [22, 23, 24, 25, 26, 27],
#  '000213.jpg': [28, 29],
#  '000333.jpg': [16, 17, 18, 19, 20, 21]}
